# %%
! pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=ee97b7fbf948447851adeded28e66cc0e4ee1178c4657c99d488e06dd87c2136
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark import SparkContext
import numpy as np

# Initialize SparkContext
sc = SparkContext("local", "RDD Tasks")

# Generating 100 random numbers in the range 0 to 10 using numpy randint function with the seed set to 10
np.random.seed(10)
random_numbers = np.random.randint(0, 11, 100)

# Create an RDD using the parallelize function with the data generated in the previous step
rdd = sc.parallelize(random_numbers)

# Calculate the frequency of each number (0 - 10) using the appropriate function of RDD
frequency_count = rdd.countByValue()
print(random_numbers,'\n')
# Print the frequency of each number
for number, count in sorted(frequency_count.items()):
    if count==1:
        print(f"{number} has {count} occurrences")
    else:
        print(f"{number} has {count} occurrences")
# Stop SparkContext
sc.stop()
# Out:
# [ 9  4  0  1  9  0  1 10  8  9  0 10  8  6  4  3  0  4  6  8 10  1  8  4
#   1  3  6  5  3  9  6  9  1  9  4  2  6  7  8 10  8  9  2  0  6  7  8  1
#   7  1  4 10  0  8  5  4  7  8  8  2  6  2  8  8  6  6  5 10  6  0  0  6
#   9  1  8 10  9  1  2  8  9  9  5  0  2  7  3  0  4  2  0  3  3  1  2  5
#   9  0 10  1]
#
# 0 has 12 occurrences
# 1 has 11 occurrences
# 2 has 8 occurrences
# 3 has 6 occurrences
# 4 has 8 occurrences
# 5 has 5 occurrences
# 6 has 11 occurrences
# 7 has 5 occurrences
# 8 has 14 occurrences
# 9 has 12 occurrences
# 10 has 8 occurrences

# %%
from pyspark import SparkContext

# Initialize SparkContext
sc = SparkContext("local", "RDD Tasks")

# Load the text8 dataset into an RDD
text8_rdd = sc.textFile("text8")

# Split each line into words
words = text8_rdd.flatMap(lambda line: line.split(" "))

# Map each word to a key-value pair with the word as the key and 1 as the value
word_counts = words.map(lambda word: (word, 1))

# ReduceByKey to calculate the frequency of each word
word_frequencies = word_counts.reduceByKey(lambda a, b: a + b)

# Filter the RDD to get frequencies of words containing the letter 'a'
words_with_a = word_frequencies.filter(lambda x: 'a' in x[0])

# Print the frequencies of words containing the letter 'a'
for word, frequency in words_with_a.collect():
    if frequency==1:
        print(f"{word} occurs {frequency} time")
    else:
        print(f"{word} occurs {frequency} times")
# Stop SparkContext
sc.stop()
# Out:
# Streaming output truncated to the last 5000 lines.
# amulet occurs 1 time
# aldeburgh occurs 1 time
# naze occurs 1 time
# urals occurs 1 time
# olbia occurs 1 time
# massilia occurs 3 times
# hatria occurs 2 times
# cathrine occurs 1 time
# ambers occurs 2 times
# hymenea occurs 1 time
# gedanite occurs 1 time
# gedanum occurs 1 time
# stantienite occurs 1 time
# gutta occurs 1 time
# percha occurs 1 time
# krantzite occurs 1 time
# allingite occurs 1 time
# roumanite occurs 1 time
# giaretta occurs 1 time
# catania occurs 1 time
# cesena occurs 1 time
# fiat occurs 1 time
# hukawng occurs 1 time
# nangotaimaw occurs 1 time
# mandalay occurs 1 time
# schraufite occurs 1 time
# carpathian occurs 1 time
# ambrite occurs 1 time
# coals occurs 1 time
# copaline occurs 1 time
# highgate occurs 1 time
# chemawinite occurs 1 time
# cedarite occurs 1 time
# ammolite occurs 1 time
# labdatriene occurs 1 time
# villanueva occurs 1 time
# richa occurs 1 time
# arkivoc occurs 1 time
# emporia occurs 2 times
# gdansk occurs 1 time
# amalaric occurs 7 times
# amalarico occurs 1 time
# gesalec occurs 4 times
# languedoc occurs 1 time
# septimania occurs 1 time
# athalaric occurs 2 times
# chrotilda occurs 1 time
# konami occurs 2 times
# angelic occurs 3 times
# castlevania occurs 3 times
# fearsome occurs 1 time
# alphorn occurs 12 times
# alpenhorn occurs 6 times
# harmonics occurs 1 time
# ranz occurs 1 time
# vaches occurs 1 time
# brahms occurs 1 time
# oberland occurs 1 time
# praetorius occurs 1 time
# ricola occurs 1 time
# sinfonia occurs 1 time
# pastorella occurs 2 times
# daetwyler occurs 1 time
# farkas occurs 1 time
# jacaranda occurs 1 time
# alphorns occurs 1 time
# artiodactyla occurs 1 time
# camelidae occurs 1 time
# vicugna occurs 4 times
# pacos occurs 5 times
# mohair occurs 3 times
# mohairs occurs 1 time
# purchaser occurs 1 time
# vicuna occurs 2 times
# huarizo occurs 2 times
# huacaya occurs 7 times
# dreadlocks occurs 1 time
# alpace occurs 1 time
# industrially occurs 1 time
# fawns occurs 1 time
# upscale occurs 2 times
# regurgitated occurs 3 times
# restrain occurs 3 times
# baa occurs 2 times
# wark occurs 1 time
# warbling occurs 1 time
# paddocks occurs 1 time
# ovulate occurs 1 time
# crias occurs 1 time
# cria occurs 1 time
# camelid occurs 2 times
# steaks occurs 1 time
# lama occurs 1 time
# shear occurs 2 times
# yarn occurs 3 times
# importations occurs 1 time
# headway occurs 1 time
# outram occurs 1 time
# greetland occurs 1 time
# reattempted occurs 1 time
# camlet occurs 1 time
# warps occurs 1 time
# bradford occurs 4 times
# acclimatize occurs 1 time
# alpacaseller occurs 1 time
# stomaches occurs 1 time
# elevage occurs 1 time
# garenne occurs 1 time
# surifarm occurs 1 time
# peacetime occurs 1 time
# bioinformatics occurs 1 time
# actuarial occurs 2 times
# combinatorics occurs 1 time
# alligators occurs 11 times
# caimans occurs 3 times
# alligatoridae occurs 2 times
# alligatorinae occurs 2 times
# gharial occurs 1 time
# gavialidae occurs 1 time
# crocodilia occurs 2 times
# jagged occurs 1 time
# crocodilians occurs 1 time
# fluvial occurs 1 time
# lagarto occurs 1 time
# paleosuchus occurs 4 times
# melanosuchus occurs 5 times
# spectacled occurs 2 times
# jacare occurs 1 time
# diplocynodontinae occurs 1 time
# tadzhikosuchus occurs 1 time
# baryphracta occurs 1 time
# akantosuchus occurs 1 time
# albertochampsa occurs 1 time
# chrysochampsa occurs 1 time
# hassiacosuchus occurs 1 time
# navahosuchus occurs 1 time
# ceratosuchus occurs 1 time
# allognathosuchus occurs 1 time
# hispanochampsa occurs 1 time
# arambourgia occurs 1 time
# procaimanoidea occurs 1 time
# wannaganosuchus occurs 1 time
# prenasalis occurs 1 time
# caimaninae occurs 1 time
# eocaiman occurs 1 time
# palpebrosus occurs 1 time
# trigonatus occurs 1 time
# parussaurus occurs 1 time
# mourasuchus occurs 1 time
# yacare occurs 2 times
# apaporis occurs 1 time
# apaporiensis occurs 1 time
# lutescans occurs 1 time
# latirostris occurs 1 time
# metabolize occurs 1 time
# aliat occurs 1 time
# kamchatka occurs 6 times
# andreanof occurs 1 time
# habitable occurs 1 time
# makushin occurs 1 time
# unalaska occurs 11 times
# rainiest occurs 1 time
# herbage occurs 1 time
# practicable occurs 1 time
# basketry occurs 1 time
# stalks occurs 2 times
# unangan occurs 1 time
# interglacial occurs 2 times
# swiatoj occurs 1 time
# komandorski occurs 1 time
# adriian occurs 1 time
# adak occurs 1 time
# veniaminov occurs 1 time
# orphanage occurs 3 times
# ancsa occurs 1 time
# ounalashka occurs 1 time
# aleutianislands occurs 1 time
# alderfly occurs 1 time
# sialidae occurs 1 time
# mandibles occurs 1 time
# branchial occurs 1 time
# pupal occurs 1 time
# sialis occurs 2 times
# lutaria occurs 1 time
# chauliodes occurs 1 time
# megaloptera occurs 1 time
# alder occurs 23 times
# alnus occurs 9 times
# betulaceae occurs 1 time
# catkins occurs 6 times
# elongate occurs 1 time
# pollinated occurs 1 time
# betula occurs 1 time
# disintegrate occurs 1 time
# glutinosa occurs 3 times
# cordata occurs 2 times
# stalked occurs 1 time
# pollinating occurs 1 time
# acuminata occurs 1 time
# formosana occurs 1 time
# formosan occurs 1 time
# incana occurs 2 times
# alders occurs 4 times
# lepidoptera occurs 5 times
# fagales occurs 1 time
# alcott occurs 24 times
# fruitlands occurs 2 times
# transcendentalism occurs 2 times
# chatfield occurs 1 time
# alcox occurs 1 time
# alcocke occurs 1 time
# pedagogue occurs 1 time
# pestalozzi occurs 1 time
# abby occurs 1 time
# garrisonian occurs 1 time
# pecuniarily occurs 1 time
# pedagogy occurs 1 time
# wayside occurs 2 times
# transcendentalists occurs 2 times
# channing occurs 1 time
# louisa occurs 1 time
# gratified occurs 1 time
# canzonets occurs 1 time
# transcendentalist occurs 1 time
# diomedeidae occurs 1 time
# procellarids occurs 3 times
# procellariiformes occurs 7 times
# diomedea occurs 9 times
# wingspans occurs 3 times
# scavenging occurs 2 times
# bait occurs 5 times
# mollymawks occurs 7 times
# thalassarche occurs 4 times
# phoebastria occurs 7 times
# phoebetria occurs 5 times
# ahlquist occurs 2 times
# ornithological occurs 1 time
# thalassageron occurs 1 time
# diomedella occurs 1 time
# nealbutrus occurs 1 time
# rhothonia occurs 1 time
# julietata occurs 1 time
# galapagornis occurs 1 time
# laysanornis occurs 1 time
# penthirenia occurs 1 time
# seabird occurs 2 times
# californica occurs 1 time
# tailed occurs 4 times
# anglica occurs 1 time
# plumage occurs 3 times
# patches occurs 1 time
# cambered occurs 1 time
# gradient occurs 1 time
# anticlockwise occurs 1 time
# forager occurs 1 time
# patchily occurs 1 time
# galapagos occurs 2 times
# vagrants occurs 1 time
# gannet occurs 1 time
# forgae occurs 1 time
# shallows occurs 1 time
# forage occurs 1 time
# cephalopods occurs 1 time
# scavenge occurs 1 time
# carrion occurs 1 time
# laysan occurs 4 times
# dataloggers occurs 1 time
# beaks occurs 1 time
# scavenged occurs 1 time
# mantled occurs 3 times
# otago occurs 2 times
# headlands occurs 1 time
# aggregations occurs 1 time
# philopatric occurs 1 time
# dances occurs 3 times
# clacking occurs 1 time
# incubate occurs 1 time
# incubation occurs 2 times
# thermoregulate occurs 1 time
# alcatraz occurs 2 times
# frigatebird occurs 1 time
# frigatebirds occurs 1 time
# mollymawk occurs 1 time
# malle occurs 1 time
# fulmar occurs 1 time
# polynesians occurs 1 time
# chatham occurs 2 times
# overgrazed occurs 1 time
# flotsam occurs 1 time
# starves occurs 1 time
# scarers occurs 1 time
# exulans occurs 3 times
# antipodean occurs 1 time
# antipodensis occurs 1 time
# amsterdamensis occurs 1 time
# dabbenena occurs 1 time
# epomorpha occurs 1 time
# sanfordi occurs 1 time
# epomophora occurs 1 time
# irrorata occurs 1 time
# albatrus occurs 1 time
# immutabilis occurs 1 time
# melanophris occurs 2 times
# impavida occurs 1 time
# cauta occurs 3 times
# eremita occurs 1 time
# salvin occurs 1 time
# salvini occurs 1 time
# chrysostoma occurs 1 time
# carteri occurs 1 time
# fusca occurs 1 time
# palpebrata occurs 1 time
# aou occurs 1 time
# hanzab occurs 1 time
# acap occurs 1 time
# arachnophobia occurs 4 times
# arachnophobics occurs 2 times
# traumatizing occurs 1 time
# claustrophobia occurs 1 time
# wherabouts occurs 1 time
# psychoanal occurs 1 time
# satin occurs 1 time
# calcite occurs 6 times
# hardnesses occurs 1 time
# scratched occurs 2 times
# alabastrites occurs 1 time
# alabastron occurs 2 times
# quarried occurs 3 times
# vases occurs 4 times
# alabastra occurs 1 time
# canopic occurs 1 time
# sepulchral occurs 1 time
# soane occurs 2 times
# archdiocese occurs 1 time
# panes occurs 1 time
# stalagmitic occurs 1 time
# caverns occurs 2 times
# travertine occurs 1 time
# calcareous occurs 1 time
# banded occurs 6 times
# assiut occurs 1 time
# amarna occurs 1 time
# pedrara occurs 1 time
# tecali occurs 1 time
# puebla occurs 1 time
# tehuac occurs 1 time
# brak occurs 1 time
# nagar occurs 1 time
# marls occurs 2 times
# midlands occurs 1 time
# chellaston occurs 2 times
# fauld occurs 1 time
# staffordshire occurs 1 time
# nottinghamshire occurs 2 times
# altarpieces occurs 1 time
# afield occurs 1 time
# watchet occurs 1 time
# penarth occurs 1 time
# glamorganshire occurs 1 time
# nodular occurs 2 times
# spheroidal occurs 1 time
# lenticular occurs 1 time
# fluorspar occurs 1 time
# translucency occurs 2 times
# satiny occurs 2 times
# staircases occurs 1 time
# coarser occurs 1 time
# calcination occurs 1 time
# interstratified occurs 1 time
# volterra occurs 1 time
# agatiform occurs 1 time
# castellina occurs 2 times
# chalky occurs 1 time
# marmo occurs 1 time
# sulphate occurs 1 time
# assyrian occurs 4 times
# pigmentary occurs 1 time
# elgar occurs 1 time
# ahab occurs 15 times
# samaria occurs 4 times
# ithobaal occurs 1 time
# melkart occurs 1 time
# tyrian occurs 1 time
# baal occurs 1 time
# elijah occurs 3 times
# jehoshaphat occurs 2 times
# vassal occurs 4 times
# karkar occurs 1 time
# apamea occurs 1 time
# shalmaneser occurs 1 time
# matsir occurs 1 time
# israelite occurs 2 times
# baasha occurs 1 time
# hadadezer occurs 1 time
# hadad occurs 2 times
# aphek occurs 1 time
# ramoth occurs 1 time
# gilead occurs 1 time
# ahaziah occurs 1 time
# jehoram occurs 2 times
# naboth occurs 1 time
# monomanical occurs 1 time
# whaling occurs 1 time
# asic occurs 2 times
# dasyproctidae occurs 4 times
# dasyprocta occurs 12 times
# azara occurs 1 time
# agouti occurs 18 times
# azarae occurs 1 time
# coiban occurs 1 time
# coibae occurs 1 time
# cristata occurs 1 time
# fuliginosa occurs 1 time
# guamara occurs 1 time
# kalinowski occurs 1 time
# kalinowskii occurs 1 time
# leporina occurs 1 time
# prymnolopha occurs 1 time
# ruatan occurs 1 time
# ruatanica occurs 1 time
# myoprocta occurs 3 times
# acouchi occurs 2 times
# pratti occurs 1 time
# acouchy occurs 1 time
# paca occurs 3 times
# taczanowskii occurs 1 time
# pacas occurs 2 times
# agoutidae occurs 1 time
# agoutinae occurs 1 time
# agoutis occurs 2 times
# misunderstandings occurs 2 times
# hystricognath occurs 1 time
# variability occurs 1 time
# geminiano occurs 1 time
# montanari occurs 1 time
# subgiant occurs 2 times
# cratering occurs 1 time
# behenian occurs 1 time
# kabbalistic occurs 1 time
# caputalgol occurs 1 time
# solstation occurs 1 time
# aricns occurs 1 time
# mainstars occurs 1 time
# kaler occurs 1 time
# subgiants occurs 1 time
# chanced occurs 1 time
# pentatonic occurs 1 time
# bagpipe occurs 1 time
# bagpipes occurs 4 times
# folkways occurs 1 time
# weavers occurs 1 time
# sav occurs 1 time
# snares occurs 1 time
# wafted occurs 1 time
# arlo occurs 2 times
# hayley occurs 1 time
# westenra occurs 1 time
# baez occurs 1 time
# rerelease occurs 1 time
# easybyte occurs 1 time
# dialup occurs 2 times
# recrimination occurs 1 time
# comcast occurs 1 time
# gameline occurs 2 times
# caufield occurs 1 time
# applelink occurs 1 time
# auditorium occurs 1 time
# chatroom occurs 2 times
# caribe occurs 1 time
# bayou occurs 1 time
# antagonist occurs 1 time
# userbase occurs 1 time
# leveraging occurs 1 time
# environmentalists occurs 1 time
# biodegradable occurs 1 time
# mailings occurs 1 time
# aolers occurs 1 time
# hostmask occurs 1 time
# claris occurs 1 time
# imap occurs 1 time
# mails occurs 1 time
# chatrooms occurs 1 time
# rainman occurs 1 time
# hallissey occurs 1 time
# catwatch occurs 1 time
# cancellation occurs 3 times
# cancel occurs 3 times
# cancellations occurs 1 time
# navisoft occurs 1 time
# naviserver occurs 1 time
# aolserver occurs 1 time
# relaunch occurs 1 time
# subsidiaries occurs 1 time
# jabr occurs 3 times
# ax occurs 1 time
# abstracted occurs 2 times
# quasigroup occurs 3 times
# coalgebra occurs 1 time
# jiuzhang occurs 1 time
# suanshu occurs 1 time
# bakhshali occurs 1 time
# diophantus occurs 2 times
# arithmetica occurs 1 time
# aryabhata occurs 1 time
# brahmagupta occurs 1 time
# muqabilah occurs 1 time
# karaji occurs 1 time
# fakhri occurs 1 time
# bhaskara occurs 1 time
# bijaganita occurs 1 time
# ziauddin occurs 1 time
# ravetz occurs 1 time
# sparknotes occurs 1 time
# exampleproblems occurs 1 time
# nazareth occurs 1 time
# dialog occurs 1 time
# salutis occurs 5 times
# damnation occurs 1 time
# nostrae occurs 1 time
# humanae occurs 1 time
# reparatae occurs 1 time
# redundancy occurs 1 time
# regnal occurs 7 times
# consulares occurs 1 time
# ordinares occurs 1 time
# consulate occurs 3 times
# condita occurs 4 times
# boniface occurs 4 times
# tribunican occurs 1 time
# albinus occurs 2 times
# deposals occurs 1 time
# theophanes occurs 1 time
# judaeo occurs 1 time
# popularize occurs 1 time
# anninus occurs 1 time
# popularization occurs 2 times
# tonnenna occurs 1 time
# annunciation occurs 1 time
# alcuin occurs 17 times
# miaire occurs 1 time
# autarchy occurs 1 time
# chulalongkorn occurs 1 time
# phibunsongkhram occurs 1 time
# hijra occurs 1 time
# sacris occurs 1 time
# vernal occurs 3 times
# omar occurs 2 times
# khayy occurs 1 time
# milankovi occurs 1 time
# altavista occurs 1 time
# alterac occurs 1 time
# digram occurs 1 time
# authorised occurs 1 time
# avianca occurs 1 time
# volleyball occurs 1 time
# attovolt occurs 1 time
# covalently occurs 1 time
# amine occurs 17 times
# rabanus occurs 1 time
# maurus occurs 1 time
# otgar occurs 1 time
# mainz occurs 10 times
# ealhwine occurs 1 time
# headship occurs 1 time
# pallium occurs 4 times
# eanbald occurs 1 time
# parma occurs 1 time
# adoptionist occurs 1 time
# beato occurs 1 time
# asturias occurs 6 times
# adoptionism occurs 1 time
# preponderant occurs 1 time
# fortunatus occurs 2 times
# patribus occurs 1 time
# sanctis occurs 1 time
# eboracensis occurs 2 times
# ecclesiae occurs 3 times
# trinitatis occurs 1 time
# angilbert occurs 8 times
# palatii occurs 1 time
# iconoclasm occurs 1 time
# centula occurs 1 time
# nithard occurs 1 time
# intimacy occurs 2 times
# einhard occurs 3 times
# salutation occurs 1 time
# germaniae occurs 2 times
# traube occurs 1 time
# germanische occurs 1 time
# dimethylamide occurs 1 time
# diamine occurs 1 time
# triamine occurs 1 time
# tetraamine occurs 1 time
# anilines occurs 1 time
# basicity occurs 4 times
# aminoethanol occurs 1 time
# dimethylamine occurs 1 time
# trimethylamine occurs 1 time
# alkanols occurs 3 times
# electronegative occurs 1 time
# acetone occurs 1 time
# tetrachloride occurs 1 time
# chirality occurs 1 time
# chiral occurs 1 time
# trialkylamine occurs 1 time
# optically occurs 1 time
# solvation occurs 1 time
# elevating occurs 1 time
# delocalise occurs 1 time
# bascitiy occurs 1 time
# protonation occurs 1 time
# azides occurs 1 time
# staudinger occurs 1 time
# allylic occurs 1 time
# aza occurs 1 time
# baylis occurs 1 time
# uncontaminated occurs 1 time
# rearrangment occurs 1 time
# alkylaton occurs 1 time
# alkylation occurs 3 times
# pseudohalide occurs 1 time
# anions occurs 1 time
# acylated occurs 2 times
# acylation occurs 1 time
# aqeous occurs 1 time
# dehydrate occurs 1 time
# diazonium occurs 7 times
# carbonium occurs 2 times
# aniline occurs 1 time
# phenylamine occurs 1 time
# formaldehyde occurs 1 time
# enamines occurs 1 time
# azo occurs 3 times
# ponceau occurs 1 time
# chlorpheniramine occurs 1 time
# antihistamine occurs 1 time
# chlorpromazine occurs 1 time
# tranquilliser occurs 1 time
# sedates occurs 1 time
# acetaminophen occurs 1 time
# paracetamol occurs 1 time
# acetaminophenol occurs 1 time
# analgesic occurs 3 times
# pains occurs 5 times
# ashmun occurs 1 time
# sargent occurs 2 times
# manna occurs 1 time
# acquittal occurs 2 times
# outlaws occurs 1 time
# arbuthnot occurs 1 time
# ancaster occurs 1 time
# jourdan occurs 1 time
# boulanger occurs 1 time
# zauditu occurs 1 time
# beecham occurs 1 time
# werkman occurs 1 time
# bandleader occurs 4 times
# shapero occurs 1 time
# auerbach occurs 1 time
# donegan occurs 1 time
# aparicio occurs 1 time
# mehta occurs 1 time
# dibnah occurs 1 time
# voormann occurs 1 time
# galina occurs 1 time
# kulakova occurs 1 time
# tammi occurs 1 time
# olavo occurs 1 time
# earnhardt occurs 1 time
# nora occurs 1 time
# stokkan occurs 1 time
# castelluccio occurs 1 time
# carnie occurs 1 time
# cygan occurs 1 time
# skateboarder occurs 2 times
# kian occurs 1 time
# brandenburg occurs 21 times
# brandt occurs 1 time
# talmudist occurs 1 time
# poda occurs 1 time
# neuhaus occurs 1 time
# cavafy occurs 1 time
# verona occurs 3 times
# showa occurs 1 time
# taira occurs 2 times
# antoku occurs 1 time
# castilians occurs 2 times
# aljubarrota occurs 1 time
# girardeau occurs 3 times
# zelaya occurs 1 time
# tannu occurs 1 time
# tuva occurs 3 times
# tuvinian occurs 1 time
# tillamook occurs 1 time
# bethea occurs 1 time
# senegalese occurs 1 time
# novation occurs 2 times
# widescale occurs 1 time
# blackout occurs 2 times
# airways occurs 2 times
# hanazono occurs 1 time
# hayman occurs 1 time
# casaubon occurs 1 time
# tuscany occurs 3 times
# albemarle occurs 1 time
# krafft occurs 1 time
# holliday occurs 1 time
# castelnuovo occurs 1 time
# vall occurs 1 time
# galsworthy occurs 1 time
# aleksandar occurs 13 times
# gisela occurs 1 time
# schaeffer occurs 2 times
# vethathiri occurs 1 time
# maharishi occurs 1 time
# lina occurs 1 time
# fargas occurs 1 time
# danielle occurs 1 time
# backlund occurs 1 time
# larson occurs 1 time
# marcia occurs 2 times
# harden occurs 1 time
# earvin occurs 1 time
# brightman occurs 1 time
# brannon occurs 1 time
# braga occurs 3 times
# emmanuelle occurs 1 time
# halle occurs 2 times
# okocha occurs 1 time
# elena occurs 2 times
# baltacha occurs 1 time
# gymnast occurs 3 times
# rainald occurs 1 time
# dassel occurs 1 time
# fitzalan occurs 1 time
# arundel occurs 1 time
# tatsuoki occurs 1 time
# talbot occurs 1 time
# laporte occurs 1 time
# sabatier occurs 1 time
# stratten occurs 1 time
# gale occurs 2 times
# sondergaard occurs 1 time
# rahn occurs 2 times
# eddahab occurs 1 time
# talkers occurs 1 time
# adiabatic occurs 31 times
# amontons occurs 1 time
# monatomic occurs 3 times
# polyatomic occurs 1 time
# equipartition occurs 1 time
# arbitrarily occurs 3 times
# microstate occurs 1 time
# isothermal occurs 5 times
# adiabat occurs 6 times
# adiabats occurs 11 times
# callen occurs 2 times
# graphite occurs 1 time
# degeneracy occurs 1 time
# unanticipated occurs 1 time
# rankine occurs 1 time
# astute occurs 2 times
# leanhardt occurs 1 time
# knuuttila occurs 1 time
# lapse occurs 2 times
# adiabatically occurs 1 time
# approximates occurs 2 times
# noticably occurs 1 time
# quantified occurs 1 time
# thousandths occurs 1 time
# demagnetisation occurs 1 time
# molar occurs 2 times
# exponentiate occurs 1 time
# graphing occurs 1 time
# concave occurs 2 times
# graphed occurs 1 time
# severally occurs 1 time
# entropyandtemp occurs 1 time
# abscissa occurs 2 times
# ordinate occurs 2 times
# isobaric occurs 1 time
# quasistatic occurs 1 time
# azanides occurs 1 time
# acceptors occurs 1 time
# kevlar occurs 1 time
# beckmann occurs 1 time
# passerini occurs 1 time
# haack occurs 1 time
# linkage occurs 3 times
# kinetically occurs 1 time
# sulfonamides occurs 1 time
# acetamide occurs 1 time
# ethanamide occurs 1 time
# dimethylpropanamide occurs 1 time
# acrylamide occurs 1 time
# animus occurs 1 time
# animate occurs 2 times
# animatism occurs 1 time
# animists occurs 6 times
# animistic occurs 22 times
# wards occurs 3 times
# malignant occurs 2 times
# headhunters occurs 1 time
# transmigrates occurs 1 time
# basutus occurs 1 time
# umbra occurs 1 time
# pneuma occurs 1 time
# ruach occurs 1 time
# wilyamarraba occurs 1 time
# autohypnotic occurs 1 time
# trance occurs 3 times
# shaman occurs 1 time
# clairvoyance occurs 2 times
# automatist occurs 1 time
# bamboo occurs 3 times
# incantations occurs 1 time
# automatism occurs 1 time
# veridical occurs 1 time
# astral occurs 1 time
# animist occurs 6 times
# hallucinations occurs 2 times
# phantasmic occurs 1 time
# dualistic occurs 1 time
# incorporeal occurs 1 time
# impalpable occurs 1 time
# abode occurs 8 times
# anthropomorphization occurs 1 time
# explicable occurs 1 time
# mannhardt occurs 1 time
# fauns occurs 1 time
# satyrs occurs 1 time
# propitiate occurs 2 times
# thenceforward occurs 2 times
# abodes occurs 4 times
# inanimate occurs 1 time
# nias occurs 1 time
# tutelary occurs 2 times
# euahlayi occurs 1 time
# dakotas occurs 1 time
# ferryman occurs 1 time
# wreak occurs 1 time
# pontianak occurs 1 time
# separable occurs 1 time
# unattached occurs 2 times
# naguals occurs 2 times
# lycanthropy occurs 1 time
# banish occurs 1 time
# propitiated occurs 2 times
# familiars occurs 1 time
# departmental occurs 1 time
# animatistic occurs 1 time
# safest occurs 1 time
# spiritualized occurs 1 time
# pari occurs 1 time
# passu occurs 1 time
# scholastics occurs 1 time
# monadology occurs 1 time
# vitalism occurs 1 time
# stahl occurs 1 time
# heathens occurs 1 time
# marrett occurs 1 time
# wraiths occurs 1 time
# hallowell occurs 4 times
# lifeway occurs 1 time
# nayaka occurs 1 time
# ojibwa occurs 2 times
# shamanists occurs 1 time
# fraught occurs 2 times
# preferable occurs 2 times
# realist occurs 1 time
# garuba occurs 1 time
# marquez occurs 1 time
# vandino occurs 1 time
# vivaldi occurs 42 times
# barber occurs 3 times
# dispensation occurs 1 time
# maestro occurs 2 times
# ospedale occurs 1 time
# cantatas occurs 2 times
# raccolta occurs 1 time
# rehearse occurs 1 time
# transmissible occurs 1 time
# arias occurs 2 times
# giraud occurs 1 time
# paltry occurs 1 time
# adored occurs 1 time
# cetra occurs 2 times
# unmarked occurs 1 time
# pauper occurs 1 time
# mistranscription occurs 1 time
# karlskirche occurs 1 time
# sacher occurs 2 times
# plaques occurs 1 time
# rooseveltsplatz occurs 1 time
# casella occurs 1 time
# galuppi occurs 1 time
# fanna occurs 1 time
# italiano occurs 2 times
# emagine occurs 1 time
# macisaac occurs 1 time
# serrault occurs 1 time
# tchaikovsky occurs 2 times
# tomatis occurs 1 time
# sinfonias occurs 1 time
# oratorio occurs 3 times
# juditha occurs 2 times
# triumphans occurs 2 times
# glorias occurs 1 time
# stabat occurs 2 times
# beatus occurs 2 times
# magnificat occurs 4 times
# stagioni occurs 2 times
# dramatize occurs 1 time
# armonico occurs 2 times
# stravaganza occurs 1 time
# armonia occurs 1 time
# favorito occurs 1 time
# viela occurs 1 time
# pazzo occurs 1 time
# incoronazione occurs 1 time
# manlio occurs 1 time
# dorilla occurs 1 time
# farnace occurs 1 time
# rosilena occurs 1 time
# oronta occurs 1 time
# fida occurs 3 times
# ninfa occurs 1 time
# olimpiade occurs 1 time
# bajazet occurs 1 time
# tamerlano occurs 1 time
# griselda occurs 1 time
# catone occurs 1 time
# utica occurs 1 time
# rosmira occurs 1 time
# mandolin occurs 1 time
# mandoline occurs 1 time
# mandolins occurs 1 time
# sopranino occurs 3 times
# adiuvandum occurs 1 time
# laetatus occurs 1 time
# galante occurs 1 time
# giardino occurs 1 time
# gabrieli occurs 1 time
# dantley occurs 1 time
# lamo occurs 1 time
# aar occurs 5 times
# aare occurs 3 times
# canton occurs 1 time
# hasli occurs 1 time
# handegg occurs 1 time
# guttannen occurs 1 time
# swampy occurs 1 time
# interlaken occurs 1 time
# kander occurs 2 times
# saane occurs 2 times
# sarine occurs 2 times
# nears occurs 1 time
# aarberg occurs 1 time
# hagneck occurs 1 time
# nidau occurs 1 time
# gravels occurs 1 time
# aarburg occurs 1 time
# hallwiler occurs 1 time
# limmat occurs 2 times
# waldshut occurs 1 time
# sarner occurs 1 time
# furkareuss occurs 1 time
# zihlkanal occurs 1 time
# allenbach occurs 1 time
# canyons occurs 1 time
# agbar occurs 1 time
# edessa occurs 2 times
# abgarus occurs 1 time
# eisenman occurs 1 time
# thaddeus occurs 1 time
# osrhoeans occurs 1 time
# abbotsford occurs 8 times
# cartleyhole occurs 1 time
# clarty occurs 1 time
# ashestiel occurs 1 time
# parallelogram occurs 1 time
# baronial occurs 2 times
# lockhart occurs 1 time
# granddaughter occurs 9 times
# bannatyne occurs 1 time
# maitland occurs 1 time
# avraham occurs 1 time
# baha occurs 1 time
# avram occurs 1 time
# masoretic occurs 2 times
# lahire occurs 1 time
# terah occurs 3 times
# chaldees occurs 3 times
# chaldeans occurs 1 time
# maimonides occurs 1 time
# khaldis occurs 2 times
# urartu occurs 1 time
# kutha occurs 1 time
# harran occurs 1 time
# carrhae occurs 1 time
# habor occurs 1 time
# sarai occurs 9 times
# haran occurs 10 times
# ura occurs 2 times
# ebla occurs 1 time
# urau occurs 1 time
# forefathers occurs 1 time
# nahor occurs 1 time
# theophany occurs 1 time
# oaks occurs 2 times
# mamre occurs 2 times
# gerar occurs 1 time
# abimelech occurs 1 time
# handmaid occurs 1 time
# hagar occurs 6 times
# barrenness occurs 1 time
# heareth occurs 1 time
# moriah occurs 1 time
# beersheba occurs 1 time
# akedah occurs 1 time
# sages occurs 2 times
# sheba occurs 2 times
# machpelah occurs 1 time
# begat occurs 1 time
# recanted occurs 1 time
# unscathed occurs 1 time
# recant occurs 2 times
# yetzirah occurs 1 time
# progenator occurs 1 time
# figurative occurs 1 time
# eucharistic occurs 1 time
# ismail occurs 10 times
# ullah occurs 1 time
# millat occurs 2 times
# mecca occurs 4 times
# dua occurs 1 time
# salat occurs 1 time
# masjid occurs 1 time
# haram occurs 1 time
# maqam occurs 1 time
# spritual occurs 1 time
# haply occurs 1 time
# qura occurs 1 time
# azar occurs 2 times
# tarakh occurs 1 time
# qisas occurs 1 time
# anbiya occurs 1 time
# kathir occurs 1 time
# teased occurs 1 time
# reincarnated occurs 1 time
# jumrah occurs 1 time
# adha occurs 1 time
# keturah occurs 3 times
# brahma occurs 3 times
# saraisvati occurs 2 times
# sabean occurs 1 time
# miscalculating occurs 1 time
# inconsiderate occurs 1 time
# nebaioth occurs 1 time
# midian occurs 2 times
# genealogies occurs 1 time
# ethnological occurs 1 time
# aramean occurs 1 time
# parting occurs 1 time
# havilah occurs 1 time
# abrahams occurs 1 time
# joktan occurs 1 time
# chieftain occurs 3 times
# amorites occurs 2 times
# ramu occurs 1 time
# elam occurs 2 times
# amraphel occurs 1 time
# shinar occurs 2 times
# arioch occurs 1 time
# ellasar occurs 1 time
# eriaku occurs 1 time
# larsa occurs 1 time
# chedorlaomer occurs 1 time
# elamite occurs 1 time
# lagamer occurs 1 time
# gazza occurs 1 time
# tudhaliya occurs 1 time
# mimimalists occurs 1 time
# clearvisionpk occurs 1 time
# bradshaw occurs 1 time
# wiseman occurs 1 time
# patriarchal occurs 1 time
# abrasax occurs 8 times
# abracax occurs 1 time
# engraved occurs 5 times
# amulets occurs 2 times
# abracadabra occurs 1 time
# chimera occurs 1 time
# anguipede occurs 1 time
# basilideans occurs 1 time
# emanated occurs 1 time
# cabalistic occurs 1 time
# indecipherable occurs 1 time
# enigmas occurs 1 time
# latins occurs 9 times
# almighty occurs 1 time
# imaginings occurs 1 time
# untrammelled occurs 1 time
# talismans occurs 1 time
# basilidian occurs 1 time
# abrasaxtes occurs 1 time
# abraxo occurs 1 time
# bellermann occurs 1 time
# montfaucon occurs 1 time
# franck occurs 3 times
# schwab occurs 1 time
# cabbala occurs 1 time
# cabbalists occurs 1 time
# catalogues occurs 1 time
# raziel occurs 1 time
# ineffable occurs 2 times
# paraphrase occurs 1 time
# permutations occurs 1 time
# principalities occurs 3 times
# arousing occurs 1 time
# phantasm occurs 1 time
# martyrdoms occurs 1 time
# speaketh occurs 1 time
# aeons occurs 1 time
# emanations occurs 1 time
# pantheus occurs 1 time
# mithras occurs 1 time
# agathodaimon occurs 1 time
# flail occurs 1 time
# occultopedia occurs 1 time
# absalom occurs 22 times
# faulkner occurs 2 times
# achitophel occurs 1 time
# watercolor occurs 1 time
# avshalom occurs 3 times
# alom occurs 1 time
# handsomest occurs 1 time
# tamar occurs 5 times
# amnon occurs 7 times
# apparelled occurs 1 time
# sheepshearers occurs 1 time
# baalhazor occurs 1 time
# ephraim occurs 3 times
# talmai occurs 1 time
# joab occurs 6 times
# adonijah occurs 1 time
# gath occurs 1 time
# ahimaaz occurs 1 time
# ahithophel occurs 1 time
# spears occurs 3 times
# heap occurs 1 time
# vanden occurs 1 time
# plas occurs 1 time
# stargate occurs 3 times
# thema occurs 1 time
# abidos occurs 2 times
# atlantiques occurs 2 times
# abdju occurs 1 time
# reliquary occurs 1 time
# araba occurs 1 time
# madfuna occurs 1 time
# madfan occurs 1 time
# merneptah occurs 1 time
# upuaut occurs 1 time
# anhur occurs 1 time
# anubis occurs 1 time
# unbaked occurs 1 time
# hearth occurs 3 times
# glazed occurs 1 time
# inlaid occurs 1 time
# glaze occurs 1 time
# processional occurs 2 times
# ahmose occurs 2 times
# rameses occurs 2 times
# adoration occurs 1 time
# caulfield occurs 1 time
# mineptah occurs 1 time
# mariette occurs 3 times
# matting occurs 1 time
# sealings occurs 1 time
# ayrton occurs 2 times
# maclver occurs 1 time
# amrah occurs 1 time
# garstang occurs 1 time
# arabah occurs 1 time
# khasekhemwy occurs 1 time
# squarer occurs 1 time
# nagara occurs 1 time
# milesians occurs 1 time
# leander occurs 1 time
# mahommed occurs 3 times
# roncevaux occurs 1 time
# saracens occurs 1 time
# lumphanan occurs 1 time
# vardzia occurs 1 time
# headquartes occurs 1 time
# fernao occurs 1 time
# loyola occurs 2 times
# asuncion occurs 1 time
# arequipa occurs 1 time
# kagoshima occurs 1 time
# mayflower occurs 1 time
# satsuma occurs 2 times
# sante occurs 1 time
# caserio occurs 1 time
# sadi occurs 2 times
# assesination occurs 1 time
# jawaharlal occurs 1 time
# schumann occurs 1 time
# coltrane occurs 1 time
# downbeat occurs 1 time
# anniversarial occurs 1 time
# takeo occurs 1 time
# yasukuni occurs 1 time
# mirapuri occurs 1 time
# omagh occurs 1 time
# roadblock occurs 1 time
# padua occurs 2 times
# roadbuilder occurs 1 time
# franko occurs 1 time
# aurobindo occurs 1 time
# brzechwa occurs 1 time
# aleks occurs 1 time
# janusz occurs 1 time
# zajdel occurs 1 time
# vartan occurs 1 time
# mahamandaleshwar occurs 1 time
# paramhans occurs 1 time
# maheshwarananda occurs 1 time
# khaleda occurs 1 time
# zia occurs 4 times
# raakhee occurs 1 time
# gulzar occurs 1 time
# digard occurs 1 time
# daba occurs 1 time
# diawara occurs 1 time
# malian occurs 1 time
# ivanek occurs 1 time
# debra occurs 1 time
# affleck occurs 1 time
# natasha occurs 1 time
# cassina occurs 1 time
# lilia occurs 1 time
# podkopayeva occurs 1 time
# alexius occurs 48 times
# philippa occurs 2 times
# hainault occurs 1 time
# lautrec occurs 1 time
# schall occurs 1 time
# constantin occurs 1 time
# ncoveanu occurs 1 time
# wallachia occurs 2 times
# marin occurs 1 time
# marais occurs 1 time
# parini occurs 1 time
# gadolin occurs 1 time
# grazia occurs 1 time
# deledda occurs 1 time
# schnabel occurs 1 time
# prandtl occurs 1 time
# magritte occurs 1 time
# rahman occurs 1 time
# casson occurs 1 time
# amarsinh occurs 1 time
# chaudhary occurs 1 time
# acadie occurs 1 time
# ferragosto occurs 1 time
# feriae occurs 1 time
# bianca occurs 1 time
# naadym occurs 1 time
# isma occurs 1 time
# ayyad occurs 2 times
# imad occurs 1 time
# abulfeda occurs 2 times
# alfida occurs 1 time
# afdal occurs 2 times
# hamah occurs 2 times
# ayyub occurs 1 time
# saladin occurs 1 time
# mameluke occurs 1 time
# nasir occurs 1 time
# salhn occurs 1 time
# abridgment occurs 3 times
# tabular occurs 1 time
# acacia occurs 58 times
# fraternity occurs 3 times
# gondwanian occurs 1 time
# mimosoideae occurs 1 time
# fabaceae occurs 1 time
# catclaw occurs 1 time
# wattle occurs 12 times
# mearnsii occurs 2 times
# melanoxylon occurs 2 times
# caven occurs 1 time
# wattles occurs 2 times
# pinnate occurs 2 times
# leaflets occurs 4 times
# glaucoptera occurs 1 time
# cladodes occurs 1 time
# purpureapetala occurs 1 time
# cultivar occurs 1 time
# leprosa occurs 1 time
# armata occurs 1 time
# giraffae occurs 1 time
# camelthorn occurs 1 time
# sphaerocephala occurs 1 time
# spadicigera occurs 1 time
# misapplied occurs 1 time
# robinia occurs 2 times
# pseudoacacia occurs 1 time
# hepialid occurs 1 time
# aenetus occurs 1 time
# endoclita occurs 2 times
# malabaricus occurs 2 times
# bucculatricid occurs 1 time
# bucculatrix occurs 2 times
# agilis occurs 1 time
# flexuosa occurs 1 time
# nilotica occurs 3 times
# earpod occurs 1 time
# auriculiformis occurs 1 time
# arabica occurs 2 times
# babool occurs 1 time
# ejaculation occurs 1 time
# tannin occurs 2 times
# pycnantha occurs 1 time
# attains occurs 1 time
# homalophylla occurs 1 time
# myall occurs 1 time
# sabicu occurs 1 time
# seyal occurs 2 times
# shittah occurs 1 time
# heterophylla occurs 1 time
# koa occurs 1 time
# farnesiana occurs 1 time
# fragrance occurs 1 time
# astringent occurs 2 times
# catechu occurs 2 times
# evaporating occurs 1 time
# ornamentals occurs 1 time
# glaucous occurs 1 time
# mimosa occurs 2 times
# feathery occurs 1 time
# pennata occurs 1 time
# alkaloids occurs 2 times
# maoi occurs 1 time
# ayahuasca occurs 1 time
# tihkal occurs 1 time
# baileyana occurs 1 time
# tryptamine occurs 4 times
# carbolines occurs 1 time
# maidenii occurs 1 time
# albida occurs 1 time
# confusa occurs 1 time
# laeta occurs 1 time
# mellifera occurs 1 time
# phlebophylla occurs 1 time
# podalyriaefolia occurs 1 time
# sieberiana occurs 1 time
# simplicifolia occurs 1 time
# unforgettable occurs 1 time
# pantropical occurs 1 time
# acapulco occurs 30 times
# hinterland occurs 1 time
# abra occurs 1 time
# nahuatl occurs 1 time
# metates occurs 1 time
# curvaceous occurs 1 time
# tarascan occurs 1 time
# zapotec occurs 1 time
# aztec occurs 2 times
# zacatula occurs 1 time
# zaro occurs 1 time
# rdenas occurs 1 time
# michoac occurs 1 time
# urdaneta occurs 1 time
# tradewinds occurs 1 time
# galleon occurs 4 times
# bargained occurs 1 time
# porcelain occurs 1 time
# lacquerware occurs 1 time
# marauders occurs 1 time
# cabo occurs 1 time
# aleman occurs 1 time
# tabares occurs 1 time
# cacao occurs 1 time
# beans occurs 1 time
# canc occurs 2 times
# drugdealers occurs 1 time
# interoceanic occurs 1 time
# lvarez occurs 1 time
# agentes occurs 1 time
# federales occurs 1 time
# sitian occurs 1 time
# tras occurs 1 time
# balacera occurs 2 times
# cuatro occurs 1 time
# narcos occurs 2 times
# contradictorias occurs 1 time
# baten occurs 1 time
# balazos occurs 1 time
# acafest occurs 1 time
# apennine occurs 1 time
# dinaric occurs 1 time
# hadriaticum occurs 1 time
# adria occurs 2 times
# hadria occurs 1 time
# syracusan occurs 1 time
# gargano occurs 3 times
# inaccurately occurs 2 times
# tarentum occurs 1 time
# ostia occurs 1 time
# otranto occurs 1 time
# istria occurs 3 times
# ortona occurs 1 time
# ula occurs 2 times
# ancona occurs 2 times
# pescara occurs 1 time
# istrian occurs 1 time
# kvarner occurs 1 time
# vidova occurs 1 time
# gora occurs 1 time
# ilija occurs 1 time
# boka occurs 1 time
# kotorska occurs 1 time
# cattaro occurs 1 time
# korkyra occurs 1 time
# melaina occurs 1 time
# izola occurs 1 time
# piran occurs 1 time
# rijeka occurs 1 time
# zadar occurs 1 time
# bora occurs 1 time
# bura occurs 1 time
# squalls occurs 1 time
# maestral occurs 1 time
# amphidromic occurs 1 time
# geabios occurs 2 times
# inaugurates occurs 1 time
# arica occurs 2 times
# carmack occurs 2 times
# baranja occurs 1 time
# slavonia occurs 1 time
# krka occurs 1 time
# fastball occurs 1 time
# mays occurs 1 time
# panzram occurs 1 time
# crashlands occurs 1 time
# keidanren occurs 1 time
# ishikawa occurs 2 times
# khanh occurs 1 time
# demonstrators occurs 2 times
# lorean occurs 1 time
# cecelia occurs 1 time
# cichan occurs 1 time
# debian occurs 1 time
# janklow occurs 1 time
# manslaughter occurs 1 time
# machiques occurs 1 time
# plantagenet occurs 2 times
# agostino occurs 2 times
# carracci occurs 1 time
# lippmann occurs 1 time
# laforgue occurs 2 times
# stagg occurs 1 time
# bernarr occurs 1 time
# mcfadden occurs 1 time
# meany occurs 1 time
# liane occurs 1 time
# haid occurs 1 time
# fernandes occurs 1 time
# announcer occurs 3 times
# newmar occurs 1 time
# newsreader occurs 1 time
# massoud occurs 1 time
# barzani occurs 1 time
# hasely occurs 1 time
# kathie occurs 1 time
# farriss occurs 1 time
# bassett occurs 2 times
# ulrika occurs 1 time
# mateja occurs 1 time
# lazaridis occurs 1 time
# krisztina occurs 1 time
# jonatan occurs 1 time
# kyal occurs 1 time
# wenceslaus occurs 1 time
# yoshikatsu occurs 1 time
# marvell occurs 1 time
# tindal occurs 1 time
# ramakrishna occurs 1 time
# paramahansa occurs 1 time
# hlinka occurs 2 times
# bela occurs 1 time
# langmuir occurs 1 time
# wanda occurs 1 time
# landowska occurs 1 time
# harpsichordist occurs 1 time
# selman occurs 1 time
# waksman occurs 1 time
# ukrainain occurs 1 time
# diefenbaker occurs 1 time
# averill occurs 1 time
# amanda occurs 2 times
# nidal occurs 1 time
# ugandan occurs 1 time
# quiroga occurs 1 time
# taiz occurs 1 time
# acheiropoietos occurs 1 time
# mandelion occurs 1 time
# palio occurs 1 time
# assunta occurs 1 time
# adjunct occurs 3 times
# sketchpad occurs 1 time
# palo occurs 1 time
# smalltalk occurs 3 times
# dynabook occurs 2 times
# adele occurs 1 time
# squeak occurs 1 time
# learners occurs 1 time
# imagineers occurs 1 time
# typeball occurs 1 time
# incarnations occurs 1 time
# monadic occurs 2 times
# dyadic occurs 2 times
# iota occurs 5 times
# workspace occurs 3 times
# leftarrow occurs 3 times
# manugistics occurs 1 time
# jsoftware occurs 1 time
# downarrow occurs 3 times
# negate occurs 1 time
# perpetuated occurs 1 time
# adverb occurs 1 time
# micheal occurs 2 times
# montalbano occurs 2 times
# nial occurs 1 time
# adin occurs 3 times
# falkoff occurs 3 times
# doctoral occurs 1 time
# abrams occurs 1 time
# sigapl occurs 1 time
# algo occurs 1 time
# anguage occurs 2 times
# fortran occurs 1 time
# bracketed occurs 1 time
# niklaus occurs 1 time
# ial occurs 1 time
# nternational occurs 1 time
# syntaxes occurs 2 times
# commas occurs 1 time
# backus occurs 4 times
# naur occurs 4 times
# aphoristic occurs 1 time
# bloatedness occurs 1 time
# transput occurs 1 time
# adriaan occurs 1 time
# wijngaarden occurs 2 times
# grammars occurs 2 times
# parser occurs 1 time
# absmax occurs 2 times
# sameline occurs 2 times
# jovial occurs 1 time
# valgol occurs 1 time
# surnames occurs 2 times
# ernighan occurs 1 time
# datatype occurs 1 time
# formatted occurs 1 time
# broadbased occurs 1 time
# dynamically occurs 2 times
# braces occurs 1 time
# foobar occurs 2 times
# concatenation occurs 1 time
# optionally occurs 1 time
# whitespace occurs 1 time
# nawk occurs 1 time
# kernighan occurs 1 time
# gawk occurs 7 times
# xgawk occurs 2 times
# loadable occurs 1 time
# mawk occurs 2 times
# auk occurs 1 time
# xmlgawk occurs 1 time
# bracket occurs 1 time
# madura occurs 1 time
# nadu occurs 1 time
# compasses occurs 1 time
# renovation occurs 3 times
# wrangler occurs 1 time
# brougham occurs 2 times
# scotsman occurs 3 times
# cyclopedia occurs 2 times
# congenial occurs 1 time
# arithmeticians occurs 1 time
# actuaries occurs 1 time
# sophia occurs 4 times
# illustrative occurs 1 time
# martineau occurs 1 time
# bain occurs 2 times
# prostration occurs 1 time
# controversialist occurs 1 time
# hamiltons occurs 1 time
# baronet occurs 3 times
# irishman occurs 5 times
# polars occurs 1 time
# geniality occurs 1 time
# seaside occurs 4 times
# athen occurs 2 times
# permanence occurs 2 times
# chrystal occurs 1 time
# attentive occurs 1 time
# pleases occurs 1 time
# refractory occurs 2 times
# illogical occurs 2 times
# formalist occurs 1 time
# formalists occurs 1 time
# enumerated occurs 2 times
# contradicts occurs 2 times
# quadruple occurs 2 times
# phrased occurs 1 time
# consanguinity occurs 1 time
# paradoxer occurs 8 times
# crackpot occurs 1 time
# depravation occurs 1 time
# contrivance occurs 1 time
# heralded occurs 1 time
# assented occurs 4 times
# verbatim occurs 1 time
# bookstands occurs 1 time
# squarers occurs 1 time
# duplicators occurs 1 time
# stagnators occurs 1 time
# paradoxers occurs 1 time
# dissemination occurs 1 time
# goliath occurs 3 times
# quadrative occurs 1 time
# cracked occurs 1 time
# rapping occurs 1 time
# unimagined occurs 1 time
# determinate occurs 1 time
# heath occurs 1 time
# asgard occurs 4 times
# sgar occurs 2 times
# midgard occurs 2 times
# freyja occurs 1 time
# svadilfari occurs 1 time
# idavoll occurs 1 time
# gladsheim occurs 1 time
# yggdrasill occurs 1 time
# anglicizations occurs 2 times
# sgard occurs 2 times
# sgardr occurs 1 time
# asgardr occurs 1 time
# sgarthr occurs 1 time
# sgarth occurs 1 time
# asgarth occurs 1 time
# sgardhr occurs 1 time
# asg occurs 1 time
# asgaard occurs 1 time
# skylab occurs 16 times
# retroactively occurs 1 time
# chaffee occurs 1 time
# fuselage occurs 1 time
# salyut occurs 1 time
# batch occurs 1 time
# stoppages occurs 1 time
# wasteful occurs 1 time
# interagency occurs 1 time
# aggravate occurs 1 time
# serviceman occurs 1 time
# brilliantly occurs 3 times
# minuteman occurs 1 time
# machining occurs 1 time
# fabricating occurs 1 time
# environmentalism occurs 1 time
# orbitar occurs 1 time
# suborbital occurs 2 times
# transonic occurs 1 time
# rehearsal occurs 1 time
# brainchild occurs 1 time
# fernbank occurs 1 time
# antares occurs 1 time
# usaf occurs 1 time
# patterson occurs 1 time
# dayton occurs 2 times
# astp occurs 1 time
# kranz occurs 1 time
# chaikin occurs 2 times
# autobiograpy occurs 1 time
# panoramas occurs 1 time
# aggravated occurs 2 times
# patting occurs 1 time
# misdemeanor occurs 5 times
# subparagraph occurs 1 time
# menacing occurs 2 times
# inchoate occurs 1 time
# threateningly occurs 1 time
# sadomasochistic occurs 1 time
# spanner occurs 1 time
# caning occurs 1 time
# adminster occurs 1 time
# vigilantes occurs 1 time
# affray occurs 1 time
# bashing occurs 1 time
# alfheim occurs 5 times
# lfar occurs 6 times
# elfhame occurs 3 times
# elphame occurs 4 times
# elfland occurs 3 times
# elfenland occurs 2 times
# stanza occurs 3 times
# ydalir occurs 1 time
# gylfaginning occurs 1 time
# blacker occurs 1 time
# andlang occurs 1 time
# andlangr occurs 1 time
# heima occurs 1 time
# rowland occurs 3 times
# anglicized occurs 1 time
# ynglinga occurs 3 times
# raumelfr occurs 1 time
# raum occurs 7 times
# glomma occurs 2 times
# gautelfr occurs 1 time
# gaut occurs 4 times
# raumar occurs 4 times
# gautland occurs 1 time
# taland occurs 1 time
# kingssonar occurs 2 times
# gamli occurs 1 time
# svanhild occurs 1 time
# svanhildr occurs 1 time
# dagr occurs 1 time
# dayspring occurs 1 time
# mundilfari occurs 1 time
# svandhild occurs 1 time
# svan occurs 2 times
# svanr occurs 1 time
# rau occurs 1 time
# fari occurs 3 times
# ttar occurs 1 time
# saxo occurs 1 time
# grammaticus occurs 1 time
# danorum occurs 1 time
# gand occurs 21 times
# lfarr occurs 1 time
# lfarin occurs 2 times
# lfarinn occurs 1 time
# bravalla occurs 1 time
# misidentification occurs 1 time
# garbled occurs 1 time
# slaug occurs 2 times
# slaugr occurs 1 time
# ragnhild occurs 1 time
# ragnhildr occurs 1 time
# halfdan occurs 8 times
# fairhair occurs 7 times
# illuga occurs 1 time
# arf occurs 1 time
# stra occurs 1 time
# alfrun occurs 1 time
# tyrannized occurs 1 time
# heimskringla occurs 2 times
# geirstada occurs 1 time
# geirsta occurs 1 time
# contemparies occurs 1 time
# regaining occurs 1 time
# haki occurs 4 times
# anundsson occurs 1 time
# alfar occurs 1 time
# alfarin occurs 1 time
# alfgeir occurs 1 time
# alfhild occurs 1 time
# aslaug occurs 1 time
# finnalf occurs 1 time
# gandalf occurs 1 time
# grimnismal occurs 1 time
# lfdan occurs 1 time
# raumarike occurs 1 time
# raumarik occurs 1 time
# saefari occurs 1 time
# embla occurs 3 times
# anker occurs 2 times
# semidarkness occurs 1 time
# tjatsi occurs 1 time
# selma occurs 2 times
# oostanaula occurs 1 time
# etowah occurs 1 time
# wetumpka occurs 2 times
# paulding occurs 1 time
# tallassee occurs 1 time
# alanus occurs 3 times
# montepessulano occurs 1 time
# universalis occurs 2 times
# planctu occurs 1 time
# naturae occurs 1 time
# anticlaudianus occurs 2 times
# agreeably occurs 1 time
# latinity occurs 1 time
# catholicae occurs 2 times
# geometrically occurs 1 time
# factitious occurs 1 time
# corollary occurs 1 time
# auxerre occurs 2 times
# memoriale occurs 1 time
# dicta occurs 1 time
# alani occurs 1 time
# lapide occurs 1 time
# haereticos occurs 1 time
# alamanni occurs 34 times
# allemanni occurs 1 time
# alemanni occurs 4 times
# warbands occurs 2 times
# chatti occurs 1 time
# asinius occurs 1 time
# quadratus occurs 1 time
# conglomeration occurs 1 time
# alamann occurs 1 time
# elsaz occurs 1 time
# brisgavi occurs 1 time
# bucinobantes occurs 1 time
# armalausi occurs 1 time
# suabi occurs 1 time
# depredations occurs 2 times
# gallienus occurs 3 times
# gauls occurs 1 time
# vasso occurs 1 time
# galatae occurs 1 time
# martyring occurs 1 time
# francorum occurs 5 times
# swarming occurs 1 time
# benacus occurs 2 times
# argentoratum occurs 1 time
# chnodomar occurs 3 times
# chonodomarius occurs 1 time
# fredegar occurs 1 time
# aps occurs 1 time
# privatus occurs 1 time
# placentia occurs 1 time
# aurelian occurs 3 times
# fano occurs 1 time
# vindonissa occurs 1 time
# argentovaria occurs 1 time
# gratianus occurs 1 time
# alamannia occurs 3 times
# augsburg occurs 2 times
# tolbiac occurs 1 time
# carloman occurs 1 time
# summarily occurs 2 times
# alamannic occurs 2 times
# agenarich occurs 2 times
# vestralp occurs 1 time
# serapio occurs 1 time
# suomar occurs 1 time
# hortar occurs 1 time
# gundomad occurs 1 time
# vadomar occurs 2 times
# makrian occurs 1 time
# rando occurs 1 time
# hariobaud occurs 1 time
# vithicab occurs 1 time
# priarius occurs 1 time
# gebavult occurs 1 time
# leuthari occurs 2 times
# haming occurs 1 time
# lantachar occurs 1 time
# avenches occurs 3 times
# magnachar occurs 1 time
# vaefar occurs 1 time
# willehari occurs 1 time
# ortenau occurs 1 time
# lantfrid occurs 2 times
# theudebald occurs 2 times
# christianization occurs 4 times
# agathias occurs 2 times
# myrina occurs 1 time
# decapitate occurs 1 time
# alamani occurs 1 time
# columbanus occurs 3 times
# wodan occurs 1 time
# slavs occurs 1 time
# fibulae occurs 1 time
# basel occurs 4 times
# raurica occurs 1 time
# raetian occurs 1 time
# pactus occurs 1 time
# alamannorum occurs 2 times
# ecclesial occurs 1 time
# allemania occurs 1 time
# jurisdictional occurs 2 times
# martel occurs 2 times
# franconia occurs 3 times
# allemand occurs 1 time
# alem occurs 2 times
# archaeoethnology occurs 1 time
# amex occurs 6 times
# nasd occurs 2 times
# tragically occurs 1 time
# inaugurating occurs 1 time
# lakota occurs 3 times
# bombard occurs 2 times
# blacksmith occurs 1 time
# quisqueyanos occurs 1 time
# valientes occurs 1 time
# rennenkampf occurs 1 time
# stalluponen occurs 1 time
# patton occurs 1 time
# messina occurs 1 time
# camille occurs 1 time
# venera occurs 2 times
# aeroflot occurs 1 time
# azaria occurs 1 time
# haq occurs 4 times
# raphel occurs 1 time
# frankum occurs 1 time
# strathfield occurs 2 times
# taped occurs 1 time
# pravde occurs 1 time
# disengagement occurs 2 times
# hassler occurs 1 time
# albani occurs 1 time
# fermat occurs 4 times
# marlowe occurs 1 time
# shakespearean occurs 1 time
# garvey occurs 1 time
# nowak occurs 1 time
# informant occurs 1 time
# jiang occurs 1 time
# naipaul occurs 1 time
# tabakov occurs 1 time
# allison occurs 2 times
# vilas occurs 1 time
# carlisle occurs 1 time
# wahlberg occurs 1 time
# posada occurs 1 time
# tarja occurs 1 time
# gallas occurs 1 time
# eustace occurs 3 times
# fukakusa occurs 1 time
# grimmelshausen occurs 1 time
# graaf occurs 1 time
# anatomist occurs 2 times
# trediakovsky occurs 1 time
# grada occurs 1 time
# bosniak occurs 1 time
# audran occurs 1 time
# slavici occurs 1 time
# transylvanian occurs 1 time
# barraqu occurs 1 time
# temptations occurs 1 time
# souzay occurs 1 time
# bahcall occurs 1 time
# ascalon occurs 1 time
# fatimid occurs 2 times
# ilghazi occurs 1 time
# alderman occurs 2 times
# metacomet occurs 1 time
# wampanoag occurs 1 time
# raousset occurs 1 time
# guaymas occurs 1 time
# asaph occurs 2 times
# quagga occurs 1 time
# artis occurs 1 time
# magistra occurs 1 time
# iolani occurs 1 time
# detonation occurs 1 time
# thermonuclear occurs 1 time
# braybrook occurs 1 time
# acton occurs 1 time
# ogura occurs 1 time
# gunma occurs 1 time
# stoppage occurs 1 time
# lakshman occurs 1 time
# kadirgamar occurs 1 time
# infanta occurs 3 times
# eugenia occurs 2 times
# afonso occurs 108 times
# acker occurs 1 time
# balguy occurs 1 time
# financier occurs 2 times
# benavente occurs 1 time
# classicist occurs 1 time
# rinehart occurs 1 time
# radclyffe occurs 1 time
# mathewson occurs 1 time
# cabannes occurs 1 time
# hatta occurs 1 time
# nikolaevich occurs 2 times
# romanov occurs 10 times
# tsarevich occurs 12 times
# hopman occurs 1 time
# cantinflas occurs 1 time
# vikram occurs 1 time
# sarabhai occurs 1 time
# boogaloo occurs 1 time
# zan occurs 1 time
# botanist occurs 2 times
# essayist occurs 2 times
# janacek occurs 1 time
# fonda occurs 1 time
# sanchez occurs 1 time
# varlam occurs 1 time
# shalamov occurs 1 time
# sakamoto occurs 1 time
# bhakti occurs 1 time
# raksaka occurs 1 time
# sridhara occurs 1 time
# deva occurs 2 times
# gosvami occurs 1 time
# maharaja occurs 1 time
# loretta occurs 1 time
# zaraday occurs 1 time
# discordianism occurs 1 time
# envisaged occurs 1 time
# aristocrat occurs 2 times
# disallowed occurs 1 time
# amounting occurs 2 times
# isaacs occurs 1 time
# grandfathering occurs 1 time
# zoogeographical occurs 1 time
# rhacophorus occurs 1 time
# nigropalmatus occurs 1 time
# enumerates occurs 2 times
# linnean occurs 2 times
# langdon occurs 1 time
# characterise occurs 1 time
# multilateralism occurs 1 time
# crean occurs 3 times
# unshakeable occurs 1 time
# organisers occurs 1 time
# gartrell occurs 1 time
# factionally occurs 1 time
# awu occurs 3 times
# sda occurs 1 time
# amwu occurs 1 time
# asu occurs 1 time
# mua occurs 1 time
# aligns occurs 1 time
# stacking occurs 1 time
# personation occurs 1 time
# arbitrate occurs 1 time
# barcaldine occurs 1 time
# balmain occurs 1 time
# deakinite occurs 1 time
# nationalise occurs 2 times
# nationalisation occurs 1 time
# calwell occurs 2 times
# repudiate occurs 1 time
# infiltration occurs 1 time
# evatt occurs 2 times
# santamaria occurs 1 time
# mannix occurs 1 time
# holman occurs 2 times
# mathew occurs 1 time
# latham occurs 1 time
# beattie occurs 1 time
# bracks occurs 1 time
# stanhope occurs 1 time
# iemma occurs 1 time
# wran occurs 1 time
# ...
# fishmeal occurs 3 times
# discards occurs 1 time
# piscinae occurs 1 time
# wyban occurs 1 time
# araki occurs 1 time
# kootenay occurs 1 time
# nelha occurs 2 times
# tenants occurs 1 time
# keahole occurs 1 time
# kailua occurs 1 time
# kona occurs 1 time
# aquanic occurs 1 time
# chapterof occurs 1 time
# oceanographic occurs 1 time
# geographyinaction occurs 1 time
# hydrography occurs 1 time
# oceanography occurs 1 time
# chaitin occurs 6 times
# concatenated occurs 1 time
# generatefixedstring occurs 2 times
# lexicographically occurs 1 time
# interpretlanguage occurs 4 times
# invariance occurs 2 times
# generatecomplexstring occurs 4 times
# generateparadoxicalstring occurs 3 times
# auspicious occurs 1 time
# concatenate occurs 1 time
# cranks occurs 1 time
# lossage occurs 1 time
# referential occurs 1 time
# nthproofprovescomplexityformula occurs 2 times
# generateprovablycomplexstring occurs 2 times
# generateprovablyparadoxicalstring occurs 2 times
# parametrisation occurs 1 time
# manin occurs 1 time
# idsia occurs 1 time
# vitanyi occurs 1 time
# grunwald occurs 1 time
# lamenting occurs 1 time
# lethean occurs 1 time
# proserpina occurs 1 time
# ottava occurs 1 time
# rima occurs 1 time
# alliteration occurs 1 time
# craves occurs 1 time
# adrift occurs 1 time
# cherasco occurs 1 time
# petacci occurs 2 times
# crewmates occurs 1 time
# adulyadej occurs 1 time
# baader occurs 1 time
# raspe occurs 1 time
# galician occurs 5 times
# contras occurs 1 time
# maui occurs 1 time
# aloha occurs 1 time
# whitewater occurs 1 time
# videotaped occurs 1 time
# millionnaire occurs 1 time
# demostration occurs 1 time
# falluja occurs 1 time
# sparry occurs 1 time
# carel occurs 1 time
# asser occurs 8 times
# kraus occurs 1 time
# abdulla occurs 1 time
# tuqay occurs 1 time
# sansom occurs 1 time
# lamborghini occurs 1 time
# kaunda occurs 1 time
# madge occurs 1 time
# margret occurs 1 time
# sharpless occurs 1 time
# cauwenberghe occurs 1 time
# strassman occurs 1 time
# nicklas occurs 1 time
# hersisia occurs 1 time
# sable occurs 1 time
# illarionovich occurs 1 time
# abicht occurs 1 time
# pinhead occurs 1 time
# freak occurs 1 time
# farinacci occurs 1 time
# jouhaux occurs 1 time
# clas occurs 1 time
# valvano occurs 1 time
# schawlow occurs 1 time
# candido occurs 1 time
# theodora occurs 1 time
# arthemius occurs 1 time
# vitalis occurs 1 time
# patritius occurs 1 time
# wantage occurs 2 times
# mercia occurs 9 times
# attractiveness occurs 1 time
# anticipatory occurs 1 time
# ethelbald occurs 1 time
# secundarius occurs 1 time
# tanist occurs 1 time
# witenagemot occurs 1 time
# aethelred occurs 2 times
# diarchy occurs 1 time
# ealhswith occurs 1 time
# ealdorman occurs 1 time
# gaini occurs 1 time
# ethelfleda occurs 1 time
# ashdown occurs 1 time
# shrivenham occurs 1 time
# marton occurs 1 time
# wareham occurs 3 times
# blockaded occurs 3 times
# chippenham occurs 2 times
# athelney occurs 4 times
# apologized occurs 1 time
# apologize occurs 1 time
# harpist occurs 1 time
# danelaw occurs 1 time
# watling occurs 1 time
# anglian occurs 4 times
# appledore occurs 2 times
# haesten occurs 4 times
# farnham occurs 1 time
# ealdormen occurs 1 time
# lea occurs 1 time
# maneuvred occurs 1 time
# northwestwards occurs 1 time
# thanehood occurs 1 time
# steadier occurs 1 time
# hierran occurs 1 time
# thesaurius occurs 1 time
# cellararius occurs 1 time
# pincerna occurs 1 time
# alfredian occurs 3 times
# cricklade occurs 1 time
# rampart occurs 2 times
# excavators occurs 1 time
# burghal occurs 3 times
# hidage occurs 3 times
# wormald occurs 1 time
# taxable occurs 1 time
# witangemot occurs 1 time
# grandiosely occurs 1 time
# wulfstan occurs 2 times
# haithabu occurs 2 times
# modwenna occurs 1 time
# inroads occurs 1 time
# grimbald occurs 1 time
# handboc occurs 1 time
# alliterating occurs 1 time
# blostman occurs 1 time
# martyrology occurs 1 time
# masque occurs 2 times
# draughtsman occurs 1 time
# doria occurs 2 times
# pamphili occurs 3 times
# ferdinando occurs 1 time
# mantua occurs 2 times
# greatand occurs 1 time
# bonacorsi occurs 1 time
# altemps occurs 1 time
# cortona occurs 1 time
# buoncompagni occurs 1 time
# beheading occurs 2 times
# barnabite occurs 1 time
# pamphilj occurs 3 times
# camillo occurs 3 times
# pancrazio occurs 1 time
# rainaldi occurs 1 time
# ignazio occurs 1 time
# marzio occurs 1 time
# velasquez occurs 1 time
# aranjuez occurs 1 time
# fuga occurs 1 time
# reinvigorated occurs 1 time
# gianlorenzo occurs 1 time
# altarpiece occurs 3 times
# dismayed occurs 1 time
# warriers occurs 1 time
# portraiture occurs 1 time
# draperies occurs 1 time
# laudivio occurs 1 time
# zacchia occurs 1 time
# frangipane occurs 1 time
# conservatori occurs 1 time
# campidoglio occurs 1 time
# classicized occurs 1 time
# ferrata occurs 1 time
# classicizing occurs 1 time
# bravura occurs 1 time
# artnet occurs 1 time
# algerus occurs 1 time
# misericordia occurs 1 time
# justitia occurs 1 time
# martene occurs 1 time
# sacramentis occurs 1 time
# sanguinis occurs 1 time
# berengarian occurs 1 time
# arbitrio occurs 1 time
# sacrificio occurs 1 time
# hauck occurs 1 time
# realencyk occurs 1 time
# jazair occurs 1 time
# agglomeration occurs 1 time
# bahdja occurs 1 time
# casbah occurs 5 times
# bab occurs 5 times
# azoun occurs 3 times
# vespasian occurs 1 time
# senhaja occurs 1 time
# almohades occurs 4 times
# wadid occurs 1 time
# amirs occurs 2 times
# wahid occurs 1 time
# arouj occurs 3 times
# pashalik occurs 1 time
# ransoming occurs 1 time
# algierian occurs 1 time
# corsair occurs 1 time
# metidja occurs 1 time
# sahat occurs 1 time
# chouhada occurs 1 time
# ketchaoua occurs 3 times
# afrique occurs 2 times
# bardo occurs 2 times
# vaults occurs 1 time
# jamaa occurs 3 times
# minbar occurs 1 time
# tachfin occurs 1 time
# cupola occurs 1 time
# cupolas occurs 1 time
# algerine occurs 1 time
# midshipman occurs 1 time
# talleyrand occurs 1 time
# djamaa occurs 1 time
# arcades occurs 1 time
# mosaics occurs 1 time
# agha occurs 4 times
# parapet occurs 1 time
# ramparts occurs 1 time
# confraternity occurs 2 times
# neapolitan occurs 1 time
# maquam occurs 1 time
# chahid occurs 1 time
# alhazen occurs 17 times
# haitham occurs 4 times
# haythen occurs 1 time
# basri occurs 1 time
# basrah occurs 3 times
# basra occurs 1 time
# mercurial occurs 1 time
# impracticality occurs 1 time
# hautham occurs 1 time
# kitab occurs 3 times
# manazir occurs 3 times
# catoptrics occurs 2 times
# magnifying occurs 1 time
# mizan occurs 1 time
# hikmah occurs 1 time
# dinars occurs 1 time
# banknote occurs 1 time
# giambattista occurs 1 time
# pecham occurs 1 time
# oticae occurs 1 time
# thesaurus occurs 1 time
# alhazeni occurs 1 time
# ascensionibus occurs 1 time
# bodleian occurs 1 time
# alhazens occurs 1 time
# almagest occurs 1 time
# haytham occurs 2 times
# saleh occurs 1 time
# beshara occurs 1 time
# islamica occurs 1 time
# daviddarling occurs 1 time
# mannerist occurs 1 time
# maniera occurs 1 time
# prato occurs 1 time
# sussana occurs 1 time
# mannerism occurs 1 time
# almoravides occurs 6 times
# murabitun occurs 1 time
# murabit occurs 3 times
# lamtuna occurs 1 time
# shariah occurs 1 time
# yahya occurs 5 times
# kairouan occurs 1 time
# kairawan occurs 1 time
# yasin occurs 4 times
# malikis occurs 1 time
# madhhab occurs 1 time
# lamtunas occurs 1 time
# ribat occurs 1 time
# sunnah occurs 1 time
# ascendence occurs 1 time
# militarism occurs 1 time
# penitential occurs 1 time
# murabits occurs 3 times
# javelins occurs 1 time
# camelmen occurs 1 time
# flanks occurs 1 time
# umar occurs 3 times
# berghouata occurs 2 times
# salih occurs 1 time
# tarif occurs 1 time
# zainab occurs 2 times
# tashfin occurs 10 times
# marrakech occurs 1 time
# chieftaincies occurs 1 time
# almoravid occurs 1 time
# algeciras occurs 1 time
# zallaqah occurs 1 time
# avowedly occurs 1 time
# ghazali occurs 1 time
# tartushi occurs 1 time
# spaniard occurs 1 time
# tortosa occurs 1 time
# fatwa occurs 1 time
# aragonese occurs 5 times
# zaragoza occurs 6 times
# muwahhids occurs 1 time
# ghanya occurs 1 time
# gasteria occurs 1 time
# haworthia occurs 1 time
# aloes occurs 24 times
# leafless occurs 1 time
# exudate occurs 2 times
# purgatives occurs 1 time
# topical occurs 2 times
# farrar occurs 3 times
# scrapes occurs 1 time
# newstarget occurs 2 times
# soaps occurs 1 time
# shampoos occurs 1 time
# iasc occurs 2 times
# eczema occurs 1 time
# purgative occurs 2 times
# vulgaris occurs 1 time
# socotrina occurs 1 time
# barbadoes occurs 3 times
# curative occurs 1 time
# venenosa occurs 1 time
# laxative occurs 1 time
# contemplating occurs 1 time
# anthraquinone occurs 2 times
# aloevera occurs 2 times
# polysaccharides occurs 1 time
# aloin occurs 5 times
# aloins occurs 2 times
# nataloins occurs 1 time
# barbaloins occurs 3 times
# aloetic occurs 1 time
# chrysammic occurs 1 time
# nataloin occurs 1 time
# barbaloin occurs 1 time
# prismatic occurs 1 time
# hydragogue occurs 1 time
# cathartic occurs 1 time
# haemorrhoids occurs 2 times
# emmenagogues occurs 1 time
# especial occurs 1 time
# amenorrhoea occurs 1 time
# agarwood occurs 2 times
# agallochon occurs 1 time
# arborescens occurs 2 times
# candelabra occurs 2 times
# aristata occurs 3 times
# barberae occurs 1 time
# shortleaf occurs 1 time
# castanea occurs 1 time
# ciliaris occurs 1 time
# comosa occurs 1 time
# clanwilliam occurs 1 time
# dichotoma occurs 3 times
# namibian occurs 1 time
# distans occurs 1 time
# glauca occurs 1 time
# khamiensis occurs 1 time
# namaqua occurs 1 time
# longistyla occurs 1 time
# karoo occurs 1 time
# ramenas occurs 1 time
# pictifolia occurs 1 time
# kouga occurs 1 time
# pillansii occurs 1 time
# bastard occurs 1 time
# plicatilis occurs 1 time
# polyphylla occurs 1 time
# pratensis occurs 1 time
# ramosissima occurs 1 time
# saponaria occurs 1 time
# tauri occurs 1 time
# variegata occurs 1 time
# zebrina occurs 1 time
# spinosissima occurs 1 time
# altmed occurs 1 time
# aloech occurs 1 time
# materia occurs 2 times
# medica occurs 2 times
# homoeopathy occurs 1 time
# alyattes occurs 3 times
# sadyattes occurs 1 time
# mermnadae occurs 2 times
# halys occurs 2 times
# cyaxares occurs 1 time
# carians occurs 1 time
# standardised occurs 1 time
# aryenis occurs 1 time
# astyages occurs 1 time
# gygaea occurs 1 time
# spiegelthal occurs 1 time
# phalli occurs 1 time
# aoc occurs 9 times
# marriageable occurs 4 times
# carnal occurs 2 times
# extraterrioriality occurs 1 time
# contravention occurs 1 time
# invalidated occurs 1 time
# prosecutable occurs 2 times
# extramarital occurs 1 time
# punishable occurs 5 times
# parental occurs 1 time
# decriminalised occurs 2 times
# underage occurs 1 time
# heterosexuals occurs 1 time
# invalidating occurs 1 time
# rsa occurs 2 times
# alypius occurs 4 times
# thagaste occurs 1 time
# vicarius occurs 1 time
# carausius occurs 1 time
# thanking occurs 1 time
# amalasuntha occurs 5 times
# amalasuentha occurs 1 time
# amalaswintha occurs 1 time
# traguilla occurs 2 times
# audofleda occurs 1 time
# eutharic occurs 1 time
# areal occurs 1 time
# matasuentha occurs 1 time
# theodahad occurs 2 times
# bolsena occurs 1 time
# amaury occurs 1 time
# bena occurs 2 times
# chartres occurs 1 time
# dialectician occurs 1 time
# amalricians occurs 2 times
# erigena occurs 1 time
# mittelalter occurs 1 time
# haureau occurs 1 time
# itendant occurs 1 time
# afonsoi occurs 1 time
# urraca occurs 11 times
# sancho occurs 13 times
# mafalda occurs 4 times
# sancha occurs 1 time
# guimar occurs 4 times
# coimbra occurs 11 times
# alphonzo occurs 6 times
# reconquista occurs 4 times
# aristocracies occurs 1 time
# zamora occurs 2 times
# mamede occurs 1 time
# overcame occurs 1 time
# trava occurs 1 time
# vanquished occurs 1 time
# lamego occurs 1 time
# amadeo occurs 2 times
# liegeman occurs 1 time
# santar occurs 2 times
# badajoz occurs 2 times
# compensated occurs 1 time
# manifestis occurs 1 time
# probatum occurs 1 time
# castilian occurs 5 times
# albon occurs 1 time
# enlargement occurs 1 time
# audacities occurs 1 time
# amends occurs 1 time
# leonora occurs 1 time
# bolognian occurs 1 time
# alcoba occurs 1 time
# unbearable occurs 1 time
# leiria occurs 1 time
# faro occurs 2 times
# algarve occurs 2 times
# guadiana occurs 1 time
# dammartin occurs 1 time
# sanches occurs 2 times
# penafiel occurs 1 time
# mistreating occurs 1 time
# marinids occurs 1 time
# trastamara occurs 1 time
# barbaric occurs 1 time
# molia occurs 1 time
# africano occurs 1 time
# sintra occurs 3 times
# duarte occurs 2 times
# barcelos occurs 2 times
# braganza occurs 6 times
# alfarrobeira occurs 1 time
# alcacer occurs 1 time
# tangiers occurs 1 time
# arzila occurs 1 time
# paternity occurs 3 times
# joana occurs 1 time
# cueva occurs 1 time
# beltraneja occurs 3 times
# adulteress occurs 1 time
# gaunt occurs 1 time
# luisa occurs 2 times
# ameixial occurs 1 time
# claros occurs 1 time
# jaffnapatam occurs 1 time
# castelo occurs 1 time
# afonsoviportugal occurs 1 time
# francisca occurs 1 time
# annullment occurs 1 time
# annulment occurs 1 time
# terceira occurs 1 time
# battler occurs 3 times
# chaste occurs 2 times
# trobador occurs 1 time
# troubadour occurs 1 time
# compostela occurs 1 time
# altons occurs 1 time
# ximena occurs 1 time
# saldana occurs 1 time
# carpio occurs 1 time
# cantar occurs 1 time
# chanson occurs 1 time
# asturian occurs 1 time
# amara occurs 4 times
# sinha occurs 1 time
# vikramaditya occurs 2 times
# hsuan occurs 1 time
# tsang occurs 1 time
# brahmins occurs 1 time
# kosha occurs 2 times
# trikanda occurs 1 time
# serampore occurs 1 time
# deslongchamps occurs 1 time
# amarakosha occurs 1 time
# infante occurs 7 times
# serrano occurs 2 times
# theresianum occurs 1 time
# carlist occurs 2 times
# campos occurs 1 time
# sagunto occurs 1 time
# plenipotentiary occurs 1 time
# canovas occurs 2 times
# castillo occurs 2 times
# acclamation occurs 1 time
# carlists occurs 1 time
# workman occurs 1 time
# tarragona occurs 1 time
# oliva occurs 1 time
# moncasi occurs 1 time
# christina occurs 2 times
# pastrycook occurs 1 time
# mateo occurs 1 time
# sagasta occurs 1 time
# fearlessly occurs 1 time
# cholera occurs 1 time
# ena occurs 2 times
# mateu occurs 1 time
# morral occurs 1 time
# bystanders occurs 1 time
# hemophiliac occurs 2 times
# edelmira occurs 1 time
# sampedro occurs 1 time
# robato occurs 1 time
# covadonga occurs 1 time
# marta occurs 1 time
# rocafort occurs 1 time
# altazarra occurs 1 time
# isabelino occurs 1 time
# segovia occurs 1 time
# beatriz occurs 1 time
# federica occurs 1 time
# alfonsa occurs 1 time
# torlonia occurs 1 time
# civitella occurs 1 time
# cristina occurs 1 time
# alejandra occurs 1 time
# marone occurs 2 times
# cinzano occurs 1 time
# navas occurs 1 time
# parejo occurs 1 time
# lanie occurs 1 time
# gaufridy occurs 1 time
# dortan occurs 1 time
# leandro occurs 2 times
# moragas occurs 3 times
# parador occurs 1 time
# sociedad occurs 1 time
# balompi occurs 1 time
# cartagena occurs 2 times
# hispanorum occurs 1 time
# romanorum occurs 1 time
# imperatorum occurs 1 time
# anacephaleosis occurs 1 time
# hispanicarum occurs 1 time
# aliquot occurs 1 time
# frankfort occurs 1 time
# arag occurs 5 times
# egea occurs 1 time
# tudela occurs 1 time
# calatayud occurs 3 times
# borja occurs 2 times
# tarazona occurs 2 times
# daroca occurs 2 times
# monreal occurs 3 times
# fraga occurs 2 times
# siresa occurs 1 time
# pedrola occurs 1 time
# huesca occurs 1 time
# alcoraz occurs 1 time
# ardenes occurs 1 time
# bailo occurs 1 time
# polygamous occurs 1 time
# sepulveda occurs 1 time
# culebra occurs 1 time
# pamplona occurs 2 times
# sobrarbe occurs 1 time
# ribagorza occurs 1 time
# sahag occurs 1 time
# raim occurs 1 time
# calixtus occurs 1 time
# agains occurs 1 time
# ejea occurs 1 time
# tauste occurs 1 time
# castellar occurs 1 time
# musta occurs 1 time
# valtierra occurs 1 time
# tamarite occurs 1 time
# litera occurs 2 times
# corella occurs 1 time
# murchante occurs 1 time
# monteagudo occurs 1 time
# cascante occurs 1 time
# ayerbe occurs 1 time
# almud occurs 1 time
# gurrea occurs 1 time
# zuera occurs 1 time
# azuda occurs 1 time
# cutanda occurs 2 times
# cervera occurs 1 time
# castell occurs 1 time
# greda occurs 1 time
# magall occurs 1 time
# alag occurs 1 time
# novillas occurs 1 time
# rueda occurs 1 time
# pila occurs 1 time
# repopulated occurs 2 times
# soria occurs 1 time
# bubierca occurs 1 time
# alhama occurs 1 time
# ariza occurs 1 time
# rida occurs 1 time
# cadiella occurs 1 time
# longares occurs 1 time
# realms occurs 1 time
# falled occurs 1 time
# bayonne occurs 2 times
# belorado occurs 1 time
# pallars occurs 1 time
# templars occurs 1 time
# hospitallers occurs 1 time
# ramiro occurs 2 times
# mequinenza occurs 1 time
# ramirez occurs 1 time
# belladonna occurs 4 times
# hippeastrum occurs 2 times
# tepals occurs 1 time
# pastorals occurs 1 time
# squamigera occurs 1 time
# alighieri occurs 2 times
# purgatorio occurs 1 time
# antillon occurs 2 times
# consummate occurs 1 time
# jaume occurs 1 time
# fadrique occurs 1 time
# constan occurs 1 time

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.types import StructType, StructField, StringType, FloatType

# Initialize Spark session
spark = SparkSession.builder.appName("DataFrame Tasks").getOrCreate()

# Define the schema for the iris JSON data
iris_schema = StructType([
    StructField("sepalLength", FloatType(), True),
    StructField("sepalWidth", FloatType(), True),
    StructField("petalLength", FloatType(), True),
    StructField("petalWidth", FloatType(), True),
    StructField("species", StringType(), True),
])

# Load the iris JSON data into a DataFrame with the defined schema
iris_df = spark.read.json("iris.json", schema=iris_schema)

# We calculate Pearson Correlation between petalLength and petalWidth
correlation_result = iris_df.stat.corr("petalLength", "petalWidth")

print(f"Pearson Correlation between petalLength and petalWidth: {correlation_result}")

# We Show columns sepalLength, sepalWidth, and species for rows with petalLength >= 1.4
df = iris_df.filter(col("petalLength") >= 1.4).select("sepalLength", "sepalWidth", "species")

print("Rows with petalLength >= 1.4:")
df.show()

# Stop Spark session
spark.stop()
# Out:
# Pearson Correlation between petalLength and petalWidth: 0.9626417198678409
# Rows with petalLength >= 1.4:
# +-----------+----------+-------+
# |sepalLength|sepalWidth|species|
# +-----------+----------+-------+
# |        4.6|       3.1| setosa|
# |        5.4|       3.9| setosa|
# |        5.0|       3.4| setosa|
# |        4.9|       3.1| setosa|
# |        5.4|       3.7| setosa|
# |        4.8|       3.4| setosa|
# |        5.7|       4.4| setosa|
# |        5.7|       3.8| setosa|
# |        5.1|       3.8| setosa|
# |        5.4|       3.4| setosa|
# |        5.1|       3.7| setosa|
# |        5.1|       3.3| setosa|
# |        4.8|       3.4| setosa|
# |        5.0|       3.0| setosa|
# |        5.0|       3.4| setosa|
# |        5.2|       3.5| setosa|
# |        4.7|       3.2| setosa|
# |        4.8|       3.1| setosa|
# |        5.4|       3.4| setosa|
# |        5.2|       4.1| setosa|
# +-----------+----------+-------+
# only showing top 20 rows
